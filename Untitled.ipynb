# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt
# suppress warning
import warnings
warnings.filterwarnings('ignore')
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import scipy
from sklearn.metrics import r2_score
from statsmodels.graphics.tsaplots import plot_acf

# %%
file_path = '/Users/morris/Downloads/Neighorhood_Indicators.xlsx'

xl = pd.ExcelFile(file_path)
data_dictionary = pd.read_excel(xl, sheet_name='Data Dictionary')
data_sheet = pd.read_excel(xl, sheet_name='Data')

column_descriptions = data_dictionary.set_index('Variable').reindex(data_sheet.columns).reset_index()
column_descriptions.rename(columns={'index': 'Variable'}, inplace=True)  
column_descriptions[['Variable', 'Description']] 
column_mapping = {row['Variable']: (row['Description'] if pd.notnull(row['Description']) else row['Variable'])
                  for index, row in column_descriptions.iterrows()}

Neighorhood_Indicators = data_sheet.rename(columns=column_mapping)

# %%
Neighorhood_Indicators
# Out:
#       region_id region_display              region_name         region_type  \
# 0           606            NYC            New York City                City
# 1           606            NYC            New York City                City
# 2           606            NYC            New York City                City
# 3           606            NYC            New York City                City
# 4           606            NYC            New York City                City
# ...         ...            ...                      ...                 ...
# 3548        503          SI 03  Tottenville/Great Kills  Community District
# 3549        503          SI 03  Tottenville/Great Kills  Community District
# 3550        503          SI 03  Tottenville/Great Kills  Community District
# 3551        503          SI 03  Tottenville/Great Kills  Community District
# 3552        503          SI 03  Tottenville/Great Kills  Community District
#
#       year  \
# 0     2000
# 1     2001
# 2     2002
# ...

# %%
bart = pd.read_csv('/Users/morris/Downloads/FC_SHD_bbl_analysis.csv')

# %%
bart
# Out:
#               bbl      standard_address  city_id      city_name  boro_id  \
# 0      1000160015      50 Battery Place        1  New York City        1
# 1      1000160020      70 Battery Place        1  New York City        1
# 2      1000160210   399 Chambers Street        1  New York City        1
# 3      1000167522   400 Chambers Street        1  New York City        1
# 4      1000787510     110 Fulton Street        1  New York City        1
# ...           ...                   ...      ...            ...      ...
# 13454  3016220051  811 Lexington Avenue        1  New York City        3
# 13455  3039980030    410 Warwick Street        1  New York City        3
# 13456  3035890021    401 Chester Street        1  New York City        3
# 13457  4155290010  20-50 Nameoke Avenue        1  New York City        4
# 13458  3037660001   273 Snediker Avenue        1  New York City        3
#
#        boro_name  cd_id                              cd_name  sba_id  \
# ...
